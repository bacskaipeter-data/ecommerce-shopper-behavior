# %%
import mlcroissant as mlc

# %%
pip install mlcroissant
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----------------------------------- ---- 1.8/2.1 MB 15.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 7.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/587.2 kB ? eta -:--:--
#    ---------------------------------------- 587.2/587.2 kB 3.3 MB/s eta 0:00:00
# ...
#   Created wheel for jsonpath-rw: filename=jsonpath_rw-1.4.0-py3-none-any.whl size=15233 sha256=1a8de3654c71fcc84b5d614c0eb82d38585a83324dae1b975072f13315812c8f
# ...

# %%
ds = mlc.Dataset(jsonld=r"C:\Users\pbacskai\OneDrive - CEE Telco Group\Documents\GitHub\ecommerce-shopper-behavior\data\metadata\e-commerce-shopper-behavior-amazonshopify-based-metadata.json")
# Out:
# WARNING:absl:WARNING: The JSON-LD `@context` is not standard. Refer to the official @context (e.g., from the example datasets in https://github.com/mlcommons/croissant/tree/main/datasets/1.0). The different keys are: {'samplingRate', 'examples', 'rai'}
# WARNING:absl:Found the following 1 warning(s) during the validation:
#   -  [Metadata(E-Commerce Shopper Behavior (Amazon/Shopify Based))] Property "http://mlcommons.org/croissant/citeAs" is recommended, but does not exist.

# %%
# Oszlopok (mezők) és leírásaik kinyerése
for record_set in ds.metadata.record_sets:
    print(f"Tábla: {record_set.name}")
    for field in record_set.fields:
        print(f" - Oszlop: {field.name}")
        print(f"   Leírás: {field.description}")
# Out:
# Tábla: e_commerce_shopper_behaviour_and_lifestyle.csv
#  - Oszlop: user_id
#    Leírás:
#  - Oszlop: age
#    Leírás:
#  - Oszlop: gender
#    Leírás:
#  - Oszlop: country
#    Leírás:
#  - Oszlop: urban_rural
#    Leírás:
#  - Oszlop: income_level
#    Leírás: USD
#  - Oszlop: employment_status
#    Leírás:
#  - Oszlop: education_level
#    Leírás:
#  - Oszlop: relationship_status
#    Leírás:
#  - Oszlop: has_children
#    Leírás:
#  - Oszlop: household_size
#    Leírás: None
#  - Oszlop: occupation
#    Leírás: None
#  - Oszlop: ethnicity
#    Leírás: None
#  - Oszlop: language_preference
#    Leírás: None
#  - Oszlop: device_type
#    Leírás: None
#  - Oszlop: weekly_purchases
#    Leírás: None
#  - Oszlop: monthly_spend
#    Leírás: None
#  - Oszlop: cart_abandonment_rate
#    Leírás: None
#  - Oszlop: review_writing_frequency
#    Leírás: None
#  - Oszlop: average_order_value
#    Leírás: None
#  - Oszlop: preferred_payment_method
#    Leírás: None
# ...
